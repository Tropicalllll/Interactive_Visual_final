# %%
import pandas as pd
df = pd.read_excel('map.xlsx').set_index('省份')
df
# Out:
#       频道   品牌名称
# 省份
# 湖南  湖南卫视  作业帮一课
# 湖南  湖南卫视    康师傅
# 湖南  湖南卫视    欧莱雅
# 湖南  湖南卫视     兰蔻
# 湖南  湖南卫视   58同城
# 湖南  湖南卫视    拼多多
# 湖南  湖南卫视     一加
# 湖南  湖南卫视     丸美
# 湖南  湖南卫视    王老吉
# 湖南  湖南卫视   西瓜视频
# 湖南  湖南卫视    康师傅
# 湖南  湖南卫视  作业帮一课
# 湖南  湖南卫视    拼多多
# 湖南  湖南卫视    读书郎
# 湖南  湖南卫视   58同城
# 湖南  湖南卫视   OPPO
# 湖南  湖南卫视     东鹏
# 湖南  湖南卫视    特仑苏
# 湖南  湖南卫视   vivo
# 湖南  湖南卫视    小天才
# 湖南  湖南卫视   58同城
# 湖南  湖南卫视    康师傅
# 湖南  湖南卫视    拼多多
# 湖南  湖南卫视     百事
# 湖南  湖南卫视    读书郎
# 湖南  湖南卫视     东鹏
# 湖南  湖南卫视   OPPO
# 湖南  湖南卫视    特仑苏
# 湖南  湖南卫视     兰蔻
# 湖南  湖南卫视    欧莱雅
# ..   ...    ...
# 海南  海南卫视     椰岛
# 海南  海南卫视     路虎
# 海南  海南卫视   贵州盘州
# 海南  海南卫视   江苏苏州
# 海南  海南卫视     春光
# 海南  海南卫视   新疆喀什
# 海南  海南卫视    碧桂园
# 海南  海南卫视  西藏日喀则
# 海南  海南卫视     完美
# 海南  海南卫视   茶界中国
# 海南  海南卫视     椰岛
# 海南  海南卫视   贵州盘州
# 海南  海南卫视     别克
# 海南  海南卫视     春光
# 海南  海南卫视   江苏苏州
# 海南  海南卫视    碧桂园
# 海南  海南卫视   新疆喀什
# 海南  海南卫视     完美
# 海南  海南卫视   海南海口
# 海南  海南卫视  西藏日喀则
# 海南  海南卫视     路虎
# 海南  海南卫视     椰岛
# 海南  海南卫视     别克
# ...

# %%
df.index.unique()
# Out:
# Index(['湖南', '浙江', '上海', '江苏', '北京', '安徽', '山东', '深圳', '江西', '天津', '湖北', '贵州',
#        '辽宁', '四川', '广东', '重庆', '河南', '黑龙江', '云南', '河北', '福建', '山西', '广西', '吉林',
#        '青海', '陕西', '内蒙古', '宁夏', '新疆', '甘肃', '西藏', '海南'],
#       dtype='object', name='省份')

# %%
#通过此代码分段搜集统计 2019年下半年每个卫视品牌赞助商数量及各品牌的赞助次数
df[:60]['品牌名称'].value_counts() #每60个为一个卫视 举例：[60:120]即为浙江卫视
# Out:
# 拼多多      6
# 康师傅      6
# OPPO     5
# 特仑苏      4
# 58同城     4
# 兰蔻       4
# 作业帮一课    4
# 东鹏       3
# 欧莱雅      3
# vivo     3
# 百事       3
# 香飘飘      2
# 读书郎      2
# 神苗       2
# 汇仁       2
# 一加       1
# 丸美       1
# 西瓜视频     1
# 小天才      1
# 喜马拉雅     1
# 王老吉      1
# 小猿口算     1
# Name: 品牌名称, dtype: int64
